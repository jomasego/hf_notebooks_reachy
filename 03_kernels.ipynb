# %% [markdown]
# # Hugging Face Kernels
# Demonstrating dynamic kernel loading from the Hugging Face hub (Targeting CUDA architectures natively).

# %%
import kernels
import torch

print("Kernels library loaded successfully.")
# The `kernels` package allows dynamically loading CUDA kernels directly from the hub.
# For example, to load a hypothetical FlashAttention kernel:
# my_kernel = kernels.load("user/flash-attention-kernel")
# Output: A compiled dynamic C++ extension ready to run natively on the GPU.
# Out:
# Kernels library loaded successfully.

# %%
# In a ZeroGPU or CUDA environment, this provides immediate performance gains without waiting for library compilation.

print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA not available. In the HF Space, this will run on ZeroGPU seamlessly!")
# Out:
# CUDA Available: False
# CUDA not available. In the HF Space, this will run on ZeroGPU seamlessly!

# %% [markdown]
# # Reachy Mini & LeRobot
# Demonstration of robotics using Hugging Face tools. This requires the physical Reachy Mini to be connected.

# %%
import lerobot
import torch
import matplotlib.pyplot as plt

print("LeRobot and Torch imported successfully.")
print(f"Using device: {\"cuda\" if torch.cuda.is_available() else (\"mps\" if torch.backends.mps.is_available() else \"cpu\")}")
# Out:
#   Cell In[1], line 6
#     print(f"Using device: {\"cuda\" if torch.cuda.is_available() else (\"mps\" if torch.backends.mps.is_available() else \"cpu\")}")
#                                                                                                                                    ^
# SyntaxError: f-string expression part cannot include a backslash

# %%
# Example: Loading a dataset or policy from lerobot
# from lerobot.common.datasets.lerobot_dataset import LeRobotDataset
# dataset = LeRobotDataset("lerobot/pusht")
# print(dataset)

# Example for Reachy Mini (pseudo-code depending on exact physical setup)
# from lerobot.scripts.control_robot import ControlRobot
# robot = ControlRobot(robot_type="reachy_mini")
# robot.connect()
# print(robot.get_state())
